# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
from IPython.display import display
import os
# os.chdir('data')

# ignore warnings
warnings.filterwarnings('ignore')
# pd.options.display.float_format = '{:,.1f}'.format
# %matplotlib inline
plotsize = (13, 5)

# %%
df_currencies = pd.read_csv('data/currency_pair_prices.csv')
df_currencies
# Out:
#            Date  EUR/USD  USD/JPY  GBP/USD  USD/CHF  USD/CAD  AUD/USD
# 0    2018-01-01   1.2010   112.66   1.3503   0.9745   1.2545   0.7805
# 1    2018-01-02   1.2059   112.30   1.3588   0.9716   1.2513   0.7830
# 2    2018-01-03   1.2014   112.50   1.3516   0.9771   1.2533   0.7836
# 3    2018-01-04   1.2068   112.75   1.3553   0.9746   1.2487   0.7864
# 4    2018-01-05   1.2030   113.08   1.3571   0.9752   1.2409   0.7864
# ..          ...      ...      ...      ...      ...      ...      ...
# 779  2020-12-25   1.2204   103.48   1.3548   0.8889   1.2869   0.7599
# 780  2020-12-28   1.2214   103.78   1.3449   0.8884   1.2845   0.7577
# 781  2020-12-29   1.2247   103.56   1.3500   0.8843   1.2817      NaN
# 782  2020-12-30   1.2295   103.17   1.3622   0.8810   1.2758   0.7684
# 783  2020-12-31   1.2214   103.21   1.3673   0.8853      NaN      NaN
#
# [784 rows x 7 columns]

# %%
df_eur = df_currencies.loc[:,['Date', 'EUR/USD']]
df_eur
# Out:
#            Date  EUR/USD
# 0    2018-01-01   1.2010
# 1    2018-01-02   1.2059
# 2    2018-01-03   1.2014
# 3    2018-01-04   1.2068
# 4    2018-01-05   1.2030
# ..          ...      ...
# 779  2020-12-25   1.2204
# 780  2020-12-28   1.2214
# 781  2020-12-29   1.2247
# 782  2020-12-30   1.2295
# 783  2020-12-31   1.2214
#
# [784 rows x 2 columns]

# %%
for x in df_eur.columns:
    print(x, type(df_eur[x]), df_eur[x].dtype)
# Out:
# Date <class 'pandas.core.series.Series'> object
# EUR/USD <class 'pandas.core.series.Series'> float64

# %%
df_eur['Date'] = pd.to_datetime(df_eur['Date'], format='%Y-%m-%d')
df_eur['Date']
# Out:
# 0     2018-01-01
# 1     2018-01-02
# 2     2018-01-03
# 3     2018-01-04
# 4     2018-01-05
#          ...
# 779   2020-12-25
# 780   2020-12-28
# 781   2020-12-29
# 782   2020-12-30
# 783   2020-12-31
# Name: Date, Length: 784, dtype: datetime64[ns]

# %%
for x in df_eur.columns:
    print(x, type(df_eur[x]), df_eur[x].dtype)
# Out:
# Date <class 'pandas.core.series.Series'> datetime64[ns]
# EUR/USD <class 'pandas.core.series.Series'> float64

# %%
df_eur.set_index('Date', inplace=True)
df_eur
# Out:
#             EUR/USD
# Date
# 2018-01-01   1.2010
# 2018-01-02   1.2059
# 2018-01-03   1.2014
# 2018-01-04   1.2068
# 2018-01-05   1.2030
# ...             ...
# 2020-12-25   1.2204
# 2020-12-28   1.2214
# 2020-12-29   1.2247
# 2020-12-30   1.2295
# 2020-12-31   1.2214
#
# [784 rows x 1 columns]

# %%
df_eur.plot()
plt.show()

# %%
df_eur.ffill(inplace=True)

# %%
df_eur.plot()
plt.show()

# %%
df_eur = df_eur.resample('D').ffill()

# %%
df_eur.plot()
plt.show()

# %% [markdown]
# ## Stationary transformations

# %% [markdown]
# #### First difference

# %%
df_eur.diff().plot()
plt.show()

# %% [markdown]
# #### Variable Percent Change

# %%
df_eur.pct_change().plot()
plt.show()

# %% [markdown]
# #### Log transformation

# %%
np.log(1 +  df_eur).plot()
plt.show()

# %% [markdown]
# ## Rolling averages

# %%
window_size = 7
rolling_window = df_eur.rolling(window_size)

# %%
print('Rolling Mean')
rolling_window.mean().dropna().plot()
plt.show()
# Out:
# Rolling Mean

# %%
print('\nRolling St. Dev')
rolling_window.std().dropna().plot()
plt.show()
# Out:
# Rolling St. Dev

# %% [markdown]
# ## Correlation

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf, month_plot, quarter_plot

# %%
df_eur_week = df_eur.resample('W').ffill()
df_eur_month = df_eur.resample('M').ffill()

# %% [markdown]
# df_eur['EUR/USD'].asfreq('M') == df_eur.resample('M').ffill()

# %%
acf_plot = plot_acf(df_eur_week, lags=100, title='Autocorrelation')
pacf_plot = plot_pacf(df_eur_week, lags=30, title='Partial Autocorrelation')

# %%
acf_plot = plot_acf(df_eur_month, lags=10, title='Autocorrelation')
pacf_plot = plot_pacf(df_eur_month, lags=10, title='Partial Autocorrelation')

# %%
df_eur
# Out:
#             EUR/USD
# Date
# 2018-01-01   1.2010
# 2018-01-02   1.2059
# 2018-01-03   1.2014
# 2018-01-04   1.2068
# 2018-01-05   1.2030
# ...             ...
# 2020-12-27   1.2204
# 2020-12-28   1.2214
# 2020-12-29   1.2247
# 2020-12-30   1.2295
# 2020-12-31   1.2214
#
# [1096 rows x 1 columns]

# %%
print('\nMonthly Data Seasonal Plot')
m_plot = quarter_plot(df_eur['EUR/USD'].asfreq('Q'))
# Out:
# Monthly Data Seasonal Plot

# %%
print('\nMonthly Data Seasonal Plot')
m_plot = month_plot(df_eur['EUR/USD'].asfreq('M'))
# Out:
# Monthly Data Seasonal Plot

# %% [markdown]
# ## DECOMPOSITOIN

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

ss_decomposition = seasonal_decompose(x=df_eur.asfreq('M'), model='additive', period=6)
estimated_trend = ss_decomposition.trend
estimated_seasonal = ss_decomposition.seasonal
estimated_residual = ss_decomposition.resid

# %%
fig, axes = plt.subplots(4, 1, sharex=True, sharey=False)
fig.set_figheight(10)
fig.set_figwidth(15)
axes[0].grid(True, which='both')
axes[0].plot(df_eur.asfreq('M'), label='Original')
axes[0].legend(loc='upper left');

axes[1].plot(estimated_trend, label='Trend')
axes[1].legend(loc='upper left');

axes[2].plot(estimated_seasonal, label='Seasonality')
axes[2].legend(loc='upper left');

axes[3].plot(estimated_residual, label='Residuals')
axes[3].legend(loc='upper left');

# %% [markdown]
# I can't see seasonality
